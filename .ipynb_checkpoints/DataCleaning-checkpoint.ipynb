# %%
# Import modules and packages
import pandas as pd
from pathlib import Path
import geopandas as gpd
import pysal as ps
from splot.mapping import vba_choropleth
import matplotlib.pyplot as plt
# Out:
# /home/aaronsodhi/virtualenvs/housepredmodel/lib/python3.8/site-packages/geopandas/_compat.py:84: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
# Set file path for data
data_folder = Path("/home/aaronsodhi/HousePricePredictionModel/data/")

# Load average price data
avg_price_ssn_adj = data_folder / "latest_month/Average-price-seasonally-adjusted-2020-11.csv"
avg_price = data_folder / "latest_month/Average-prices-2020-11.csv"
avg_price_prop_type = data_folder / "latest_month/Average-prices-Property-Type-2020-11.csv"
indices = data_folder / "latest_month/Indices-2020-11.csv"
indices_ssn_adj = data_folder / "latest_month/Indices-seasonally-adjusted-2020-11.csv"
new_and_old = data_folder / "latest_month/New-and-Old-2020-11.csv"
repossession = data_folder / "latest_month/Repossession-2020-11.csv"
sales = data_folder / "latest_month/Sales-2020-11.csv"

# Load floor space data
floor_space = data_folder / 'House_Price_per_area_(metre_squared),_2004_to_2016_by_English_region_(house_and_flat).csv'

# Load room data
room_price = data_folder / 'House_Price_per_(habitable)_room,_2004_to_2016_by_English_region_(house_and_flat)_.csv'

# %%
# Read data files

# Seasonally Adjusted Average Price
saap = pd.read_csv(avg_price_ssn_adj)

# Average Price per Property Type
appt = pd.read_csv(avg_price_prop_type)

saap['Region_Name'] = saap['Region_Name'].replace({'West Midlands Region':'West Midlands'})
saap['Region_Name'] = saap['Region_Name'].replace({'East of England':'East'})

# Price per Floor Space
ppfs = pd.read_csv(floor_space)
appt['Region_Name'].unique()
# Out:
# array(['Wales', 'England', 'Outer London', 'Inner London', 'North West',
#        'North East', 'West Midlands Region', 'East Midlands', 'London',
#        'South East', 'South West', 'East of England',
#        'Yorkshire and The Humber', 'West Midlands', 'South Yorkshire',
#        'West Yorkshire', 'Merseyside', 'Greater Manchester',
#        'Tyne and Wear', 'Northamptonshire', 'Nottinghamshire',
#        'Worcestershire', 'Somerset', 'Staffordshire', 'Warwickshire',
#        'West Sussex', 'North Yorkshire', 'Surrey', 'Suffolk',
#        'Gloucestershire', 'Essex', 'Oxfordshire', 'Devon', 'Derbyshire',
#        'Cumbria', 'Norfolk', 'East Sussex', 'Lancashire', 'Kent',
#        'Hertfordshire', 'Hampshire', 'Cambridgeshire', 'Leicestershire',
#        'Lincolnshire', 'Waltham Forest', 'Tower Hamlets', 'Lewisham',
#        'Brent', 'Bromley', 'Camden', 'Greenwich', 'Hackney',
#        'Hammersmith and Fulham', 'Harrow', 'Havering', 'Hounslow',
# ...

# %%
# Read shapefile for mapping regions
regions = gpd.read_file(data_folder / 'regions/Regions_(December_2018)_EN_BFC.shp')
regions.plot()
# Out:
# <AxesSubplot:>

# %%
# Merging cities and towns into regions
appt['Region_Name'] = appt['Region_Name'].replace('South Yorkshire','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('West Yorkshire','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Merseyside','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Greater Manchester','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Tyne and Wear','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Northamptonshire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Nottinghamshire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Worcestershire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Somerset','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Staffordshire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Warwickshire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('West Sussex','South East')
appt['Region_Name'] = appt['Region_Name'].replace('North Yorkshire','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Surrey','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Suffolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Gloucestershire','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Essex','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Oxfordshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Devon','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Derbyshire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Cumbria','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Norfolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('East Sussex','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Lancashire','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Kent','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Hertfordshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Hampshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Cambridgeshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Leicestershire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Lincolnshire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Waltham Forest','London')
appt['Region_Name'] = appt['Region_Name'].replace('Tower Hamlets','London')
appt['Region_Name'] = appt['Region_Name'].replace('Lewisham','London')
appt['Region_Name'] = appt['Region_Name'].replace('Brent','London')
appt['Region_Name'] = appt['Region_Name'].replace('Bromley','London')
appt['Region_Name'] = appt['Region_Name'].replace('Camden','London')
appt['Region_Name'] = appt['Region_Name'].replace('Greenwich','London')
appt['Region_Name'] = appt['Region_Name'].replace('Hackney','London')
appt['Region_Name'] = appt['Region_Name'].replace('Hammersmith and Fulham','London')
appt['Region_Name'] = appt['Region_Name'].replace('Harrow','London')
appt['Region_Name'] = appt['Region_Name'].replace('Havering','London')
appt['Region_Name'] = appt['Region_Name'].replace('Hounslow','London')
appt['Region_Name'] = appt['Region_Name'].replace('Islington','London')
appt['Region_Name'] = appt['Region_Name'].replace('Kensington and Chelsea','London')
appt['Region_Name'] = appt['Region_Name'].replace('Kingston upon Thames','London')
appt['Region_Name'] = appt['Region_Name'].replace('Lambeth','London')
appt['Region_Name'] = appt['Region_Name'].replace('Ealing','London')
appt['Region_Name'] = appt['Region_Name'].replace('Enfield','London')
appt['Region_Name'] = appt['Region_Name'].replace('Merton','London')
appt['Region_Name'] = appt['Region_Name'].replace('Newham','London')
appt['Region_Name'] = appt['Region_Name'].replace('Barking and Dagenham','London')
appt['Region_Name'] = appt['Region_Name'].replace('Barnet','London')
appt['Region_Name'] = appt['Region_Name'].replace('City of London','London')
appt['Region_Name'] = appt['Region_Name'].replace('City of Westminster','London')
appt['Region_Name'] = appt['Region_Name'].replace('Croydon','London')
appt['Region_Name'] = appt['Region_Name'].replace('Hillingdon','London')
appt['Region_Name'] = appt['Region_Name'].replace('Redbridge','London')
appt['Region_Name'] = appt['Region_Name'].replace('Richmond upon Thames','London')
appt['Region_Name'] = appt['Region_Name'].replace('Sutton','London')
appt['Region_Name'] = appt['Region_Name'].replace('Southwark','London')
appt['Region_Name'] = appt['Region_Name'].replace('Haringey','London')
appt['Region_Name'] = appt['Region_Name'].replace('Bexley','London')
appt['Region_Name'] = appt['Region_Name'].replace('Wandsworth','London')
appt['Region_Name'] = appt['Region_Name'].replace('Walsall','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Wigan','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Wirral','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Leeds','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Liverpool','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Bury','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Calderdale','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Kirklees','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Knowsley','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Newcastle upon Tyne','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Barnsley','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Birmingham','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Bolton','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Bradford','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Coventry','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Doncaster','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Dudley','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Rochdale','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Gateshead','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Stockport','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Sunderland','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Tameside','North West')
appt['Region_Name'] = appt['Region_Name'].replace('North Tyneside','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Oldham','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Wolverhampton','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Rotherham','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Salford','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Sandwell','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Sefton','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Sheffield','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Solihull','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('South Tyneside','North East')
appt['Region_Name'] = appt['Region_Name'].replace('St Helens','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Manchester','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Trafford','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Wakefield','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Lewes','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Lichfield','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Lincoln','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Maidstone','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Maldon','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Malvern Hills','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Mansfield','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Melton','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Mendip','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Breckland','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Brentwood','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Broadland','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Bromsgrove','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Broxbourne','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Broxtowe','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Burnley','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Cambridge','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Cannock Chase','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Canterbury','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Gravesham','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Great Yarmouth','East')
appt['Region_Name'] = appt['Region_Name'].replace('Guildford','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Hambleton','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Harborough','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Harlow','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Harrogate','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Hart','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Hastings','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Havant','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Hertsmere','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('High Peak','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Hinckley and Bosworth','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Horsham','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Huntingdonshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Hyndburn','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Ipswich','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Kettering','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace("King's Lynn and West Norfolk ",'East of England')
appt['Region_Name'] = appt['Region_Name'].replace('East Cambridgeshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('East Devon','South West')
appt['Region_Name'] = appt['Region_Name'].replace('East Hampshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('East Hertfordshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('East Lindsey','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('East Northamptonshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('East Staffordshire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Eastbourne','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Eastleigh','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Eden','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Elmbridge','South East')
appt['Region_Name'] = appt['Region_Name'].replace('East Hampshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Epping Forest','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Epsom and Ewell','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Erewash','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Mid Devon','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Mid Suffolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Mid Sussex','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Mole Valley','South East')
appt['Region_Name'] = appt['Region_Name'].replace('New Forest','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Newark and Sherwood','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Newcastle-under-Lyme','North East')
appt['Region_Name'] = appt['Region_Name'].replace('North Devon','South West')
appt['Region_Name'] = appt['Region_Name'].replace('North East Derbyshire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Adur','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Allerdale','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Amber Valley','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Arun','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Ashfield','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Lancaster','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Barrow-in-Furness','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Basildon','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Basingstoke and Deane','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Bassetlaw','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Blaby','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Bolsover','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Boston','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Braintree','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Carlisle','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Castle Point','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Charnwood','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Chelmsford','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Cheltenham','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Cherwell','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Chesterfield','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Chichester','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Chorley','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Colchester','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Copeland','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Corby','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Craven','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Crawley','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Dacorum','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Dartford','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Daventry','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Derbyshire Dales','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Dover','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Oxford','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Pendle','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Preston','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Redditch','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Reigate and Banstead','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Ribble Valley','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Richmondshire','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Rochford','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Rossendale','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Exeter','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Fareham','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Fenland','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Forest of Dean','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Fylde','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Gloucester','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Staffordshire Moorlands','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Stratford-on-Avon','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Stroud','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Surrey Heath','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Swale','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Tamworth','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Tandridge','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Teignbridge','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Tendring','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Test Valley','South East')
appt['Region_Name'] = appt['Region_Name'].replace('North Hertfordshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('North Kesteven','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('North Norfolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('North Warwickshire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('North West Leicestershire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Northampton','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Babergh','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Oadby and Wigston','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Worcester','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Worthing','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Wychavon','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Wyre','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Wyre Forest','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Rother','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Rugby','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Runnymede','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Rushcliffe','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Rushmoor','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Ryedale','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Scarborough','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Sedgemoor','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Selby','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Sevenoaks','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Folkestone and Hythe','South East')
appt['Region_Name'] = appt['Region_Name'].replace('South Cambridgeshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('South Derbyshire','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('South Hams','South West')
appt['Region_Name'] = appt['Region_Name'].replace('South Holland','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('South Kesteven','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('South Lakeland','North West')
appt['Region_Name'] = appt['Region_Name'].replace('South Norfolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('South Northamptonshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('South Oxfordshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('South Ribble','North West')
appt['Region_Name'] = appt['Region_Name'].replace('South Staffordshire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Spelthorne','South East')
appt['Region_Name'] = appt['Region_Name'].replace('South Norfolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Stafford','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Tewkesbury','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Thanet','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Three Rivers','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Tonbridge and Malling','South East')
appt['Region_Name'] = appt['Region_Name'].replace('West Suffolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Somerset West and Taunton','South West')
appt['Region_Name'] = appt['Region_Name'].replace('East Suffolk','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('South Somerset','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Ashford','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Gedling','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Gosport','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Stevenage','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Nuneaton and Bedworth','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Cotswold','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Torridge','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Tunbridge Wells','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Uttlesford','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Vale of White Horse','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Warwick','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Watford','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Waverley','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Wealden','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Wellingborough','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Welwyn Hatfield','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('West Devon','South West')
appt['Region_Name'] = appt['Region_Name'].replace('West Lancashire','South West')
appt['Region_Name'] = appt['Region_Name'].replace('West Lindsey','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('West Oxfordshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Winchester','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Woking','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Norwich','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Torfaen','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Bournemouth Christchurch and Poole','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Medway','South East')
appt['Region_Name'] = appt['Region_Name'].replace('City of Kingston upon Hull','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Carmarthenshire','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Swindon','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Slough','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Bath and North East Somerset','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Vale of Glamorgan','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Warrington','North West')
appt['Region_Name'] = appt['Region_Name'].replace('West Berkshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Wiltshire','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Windsor and Maidenhead','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Wokingham','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Leicester','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Luton','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Merthyr Tydfil','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Bridgend','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Brighton and Hove','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Buckinghamshire','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Caerphilly','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Gwynedd','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Halton','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Hartlepool','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Herefordshire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Isle of Anglesey','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Isle of Wight','South East')
appt['Region_Name'] = appt['Region_Name'].replace('East Riding of Yorkshire','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Middlesbrough','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Milton Keynes','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Monmouthshire','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Neath Port Talbot','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Newport','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Bedford','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Blackburn with Darwen','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Blackpool','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Blaenau Gwent','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Bracknell Forest','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Cardiff','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Central Bedfordshire','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Ceredigion','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Cheshire East','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Cheshire West and Chester','North West')
appt['Region_Name'] = appt['Region_Name'].replace('City of Bristol','South West')
appt['Region_Name'] = appt['Region_Name'].replace('City of Derby','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('City of Nottingham','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('City of Peterborough','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('City of Plymouth','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Conwy','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Cornwall','South West')
appt['Region_Name'] = appt['Region_Name'].replace('County Durham','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Darlington','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Denbighshire','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Dorset','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Pembrokeshire','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Portsmouth','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Powys','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Reading','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Redcar and Cleveland','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Rhondda Cynon Taf','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Flintshire','North West')
appt['Region_Name'] = appt['Region_Name'].replace('Stockton-on-Tees','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Stoke-on-Trent','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Swansea','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('Telford and Wrekin','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('North East Lincolnshire','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('North Lincolnshire','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('North Somerset','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Northumberland','North East')
appt['Region_Name'] = appt['Region_Name'].replace('Wrexham','Wales')
appt['Region_Name'] = appt['Region_Name'].replace('York','Yorkshire and The Humber')
appt['Region_Name'] = appt['Region_Name'].replace('Rutland','East Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('Shropshire','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('South Gloucestershire','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Southampton','South East')
appt['Region_Name'] = appt['Region_Name'].replace('Southend-on-Sea','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Thurrock','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('Torbay','South West')
appt['Region_Name'] = appt['Region_Name'].replace('Shetland Islands','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Renfrewshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('City of Aberdeen','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('City of Dundee','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('City of Edinburgh','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('City of Glasgow','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Clackmannanshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('North Lanarkshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Orkney Islands','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Perth and Kinross','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Midlothian','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Moray','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Renfrewshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Na h-Eileanan Siar','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('North Ayrshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('West Dunbartonshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('West Lothian','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Aberdeenshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Angus','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Argyll and Bute','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Scottish Borders','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Inverclyde','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Highland','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Falkirk','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Fife','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Stirling','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('South Ayrshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('South Lanarkshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('East Renfrewshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Dumfries and Galloway','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('East Ayrshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('East Dunbartonshire','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('East Lothian','Scotland')
appt['Region_Name'] = appt['Region_Name'].replace('Outer London','London')
appt['Region_Name'] = appt['Region_Name'].replace('Inner London','London')
appt['Region_Name'] = appt['Region_Name'].replace('West Midlands Region','West Midlands')
appt['Region_Name'] = appt['Region_Name'].replace('St Albans','East of England')
appt['Region_Name'] = appt['Region_Name'].replace('East','East of England')

# %%
appt['Region_Name'].unique()
# Out:
# array(['Wales', 'England', 'London', 'North West', 'North East',
#        'West Midlands', 'East Midlands', 'South East', 'South West',
#        'East of England', 'Yorkshire and The Humber', 'England and Wales',
#        'Scotland', 'Great Britain', 'Northern Ireland', 'United Kingdom'],
#       dtype=object)

# %%
saap.groupby('Region_Name').count()
